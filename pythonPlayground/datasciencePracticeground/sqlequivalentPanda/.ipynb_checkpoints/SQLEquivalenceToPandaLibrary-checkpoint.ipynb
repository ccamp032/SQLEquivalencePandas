# %% [markdown]
# # Manipulating Dataset using Panda Library
#
# This notebook is design to perform some tasks done in SQL using Pandas library
# <br>
# I recommend reading the SQL source to get familiar with the SQL syntax.
# <br>
# SQL Source: https://www.w3schools.com/sql/

# %%
import pandas as pd
import numpy as np

# %%
lifeExpectancy = pd.read_csv("UNdata_life_expectancy_at_birth_total_years.csv")

lifeExpectancy.head()
# Out:
#        Country  Year      Value  Value Footnotes
# 0  Afghanistan  2012  60.509122              NaN
# 1  Afghanistan  2011  60.065366              NaN
# 2  Afghanistan  2010  59.600098              NaN
# 3  Afghanistan  2009  59.112341              NaN
# 4  Afghanistan  2008  58.607098              NaN

# %% [markdown]
# # SELECT - SQL command
# In SQL, we use the SELECT command to select data from a database.
# <br>
# Mainly, we use SELECT command for column selection.
# <br>
# <br>
# In Pandas, column selection is done by passing a list of column names to your DataFrame as shown below:

# %%
lifeExpectancy[['Country','Year']].head()
# Out:
#        Country  Year
# 0  Afghanistan  2012
# 1  Afghanistan  2011
# 2  Afghanistan  2010
# 3  Afghanistan  2009
# 4  Afghanistan  2008

# %% [markdown]
# # WHERE - SQL command
# In SQL, we use the WHERE command to extract only those records that fulfill a specified condition.
# <br>
# The WHERE command is use to filter data records.
# <br>
# <br>
# In Pandas, DataFrames can be filtered in multiple ways.
# <br>
# <br>
# The most useful way is using boolean indexing as shown below.
# <br>
# Notice the statement is filtering the dataframe for which the specified condition is true.

# %%
lifeExpectancy[lifeExpectancy['Country'] == 'Italy'].head()
# Out:
#      Country  Year      Value  Value Footnotes
# 5178   Italy  2012  82.936585              NaN
# 5179   Italy  2011  82.636585              2.0
# 5180   Italy  2010  82.336585              NaN
# 5181   Italy  2009  81.936585              NaN
# 5182   Italy  2008  81.734146              NaN

# %% [markdown]
# In SQL, SQL allows us to combine boolean conditions using OR and AND operators
# <br>
# Similarly, in Pandas, we can pass multiple conditions to a DataFrame using | (OR) and & (AND) operators as shown below.

# %%
lifeExpectancy[(lifeExpectancy['Country'] == 'Italy') & (lifeExpectancy['Year'] >= 2010)]
# Out:
#      Country  Year      Value  Value Footnotes
# 5178   Italy  2012  82.936585              NaN
# 5179   Italy  2011  82.636585              2.0
# 5180   Italy  2010  82.336585              NaN

# %% [markdown]
# In SQL, we can use isnull and notnull in the WHERE command as well.
# <br>
# In Pandas, NULL checking is done using the notnull() and isnull() methods/functions.
# <br>
# <br>
# Assume we created a dataframe with the following values as shown below.

# %%
frame = pd.DataFrame( {'col1': ['A', 'B', np.NaN, 'C', 'D'], \
                       'col2': ['F', np.NaN, 'G', 'H', 'I']})
frame.head()
# Out:
#   col1 col2
# 0    A    F
# 1    B  NaN
# 2  NaN    G
# 3    C    H
# 4    D    I

# %% [markdown]
# We can show only the records where col2 IS NULL with the following line of code shown below.

# %%
frame[frame['col2'].isnull()]
# Out:
#   col1 col2
# 1    B  NaN

# %% [markdown]
# And show only records where col1 IS NULL as well.

# %%
frame[frame['col1'].isnull()]
# Out:
#   col1 col2
# 2  NaN    G

# %% [markdown]
# Similarly, we can show only records of col1 IS NOT NULL with the help of the notnull() methods/functions.

# %%
frame[frame['col1'].notnull()]
# Out:
#   col1 col2
# 0    A    F
# 1    B  NaN
# 3    C    H
# 4    D    I

# %% [markdown]
# # GROUP BY - SQL command
# In SQL, GROUP BY is used to arrange identical data into groups.
# <br>
# <br>
# In pandas, we can use groupby() method/functions.
# <br>
# The groupby() method/function typically refers to a process where we’d like to split a dataset into groups.
# <br>
# Apply some function (typically aggregation) , and then combine the groups together.
# <br>
# <br>
# The dataset is arrange by country and the size of the country as well as shown below.

# %%
lifeExpectancy.groupby('Country').size()
# Out:
# Country
# Afghanistan               53
# Albania                   53
# Algeria                   53
# Angola                    53
# Antigua and Barbuda       53
# Arab World                53
# Argentina                 53
# Armenia                   53
# Aruba                     53
# Australia                 53
# Austria                   53
# Azerbaijan                53
# Bahamas, The              53
# Bahrain                   53
# Bangladesh                53
# Barbados                  53
# Belarus                   53
# Belgium                   53
# Belize                    53
# Benin                     53
# Bermuda                   17
# Bhutan                    53
# Bolivia                   53
# Bosnia and Herzegovina    53
# Botswana                  53
# Brazil                    53
# Brunei Darussalam         53
# Bulgaria                  53
# Burkina Faso              53
# Burundi                   53
#                           ..
# Sweden                    53
# Switzerland               53
# Syrian Arab Republic      53
# Tajikistan                53
# Tanzania                  53
# Thailand                  53
# Timor-Leste               53
# Togo                      53
# Tonga                     53
# Trinidad and Tobago       53
# Tunisia                   53
# Turkey                    53
# Turkmenistan              53
# Uganda                    53
# Ukraine                   53
# United Arab Emirates      53
# United Kingdom            53
# United States             53
# Upper middle income       53
# Uruguay                   53
# Uzbekistan                53
# Vanuatu                   53
# Venezuela, RB             53
# Vietnam                   53
# Virgin Islands (U.S.)     53
# West Bank and Gaza        23
# World                     53
# Yemen, Rep.               53
# Zambia                    53
# Zimbabwe                  53
# Length: 238, dtype: int64

# %% [markdown]
# Notice that we used size() and not count().
# <br>
# This is because count() applies the function to each column, returning the number of not null records within each.

# %%
lifeExpectancy.groupby('Country').count()
# Out:
#                         Year  Value  Value Footnotes
# Country
# Afghanistan               53     53                0
# Albania                   53     53                0
# Algeria                   53     53                0
# Angola                    53     53                0
# Antigua and Barbuda       53     53                0
# Arab World                53     53                0
# Argentina                 53     53                0
# Armenia                   53     53                0
# Aruba                     53     53                0
# Australia                 53     53               26
# Austria                   53     53                0
# Azerbaijan                53     53                0
# Bahamas, The              53     53                0
# Bahrain                   53     53                0
# Bangladesh                53     53                0
# Barbados                  53     53                0
# Belarus                   53     53                0
# Belgium                   53     53                1
# Belize                    53     53                0
# Benin                     53     53                0
# Bermuda                   17     17                6
# Bhutan                    53     53                0
# Bolivia                   53     53                0
# Bosnia and Herzegovina    53     53                0
# Botswana                  53     53                0
# Brazil                    53     53                0
# Brunei Darussalam         53     53                0
# Bulgaria                  53     53                0
# Burkina Faso              53     53                0
# Burundi                   53     53                0
# ...                      ...    ...              ...
# Sweden                    53     53                0
# Switzerland               53     53                0
# Syrian Arab Republic      53     53                0
# Tajikistan                53     53                0
# Tanzania                  53     53                0
# Thailand                  53     53                0
# Timor-Leste               53     53                0
# Togo                      53     53                0
# Tonga                     53     53                0
# Trinidad and Tobago       53     53                0
# Tunisia                   53     53                1
# Turkey                    53     53                0
# Turkmenistan              53     53                0
# Uganda                    53     53                0
# Ukraine                   53     53                0
# United Arab Emirates      53     53                0
# United Kingdom            53     53                2
# United States             53     53                1
# Upper middle income       53     53                0
# Uruguay                   53     53                0
# Uzbekistan                53     53                0
# Vanuatu                   53     53                0
# Venezuela, RB             53     53                2
# Vietnam                   53     53                0
# Virgin Islands (U.S.)     53     53                3
# West Bank and Gaza        23     23                0
# World                     53     53                0
# Yemen, Rep.               53     53                0
# Zambia                    53     53                0
# Zimbabwe                  53     53                0
#
# [238 rows x 3 columns]

# %%
#Grouping by more than one column is done by passing a list of columns to the groupby() method

# %% [markdown]
# # JION - SQL command
# <br>
# In SQL, SQL is used to combine rows from two or more tables, based on a related column between them.
# <br>
# <br>
# In Pandas, JOINs can be performed with join() or merge().
# <br>
# By default, join() will join the DataFrames on their indices.
# <br>
# Each method/function has parameters allowing you to specify the type of join to perform
# <br>
# (LEFT, RIGHT, INNER, FULL) or the columns to join on (column names or indices).
# <br>
# <br>
# We'll go over the various types of JOINs.
# <br>
# <br>
# Assume we created two dataframes with the same name and structure with the following values shown below

# %%
df1 = pd.DataFrame( {'key': ['A', 'B', 'C', 'D']  , 'value' : np.random.randn(4) } )

df2 = pd.DataFrame( {'key': ['B', 'D', 'D', 'E']  , 'value' : np.random.randn(4) } )

# %% [markdown]
# # INNER JION
# <br>
# In SQL, INNER JION selects records that have matching values in both tables.
# <br>
# In Pandas, by default , merge() method/function performs an INNER JOIN as shown below.

# %%
pd.merge(df1,df2,on='key')
# Out:
#   key   value_x   value_y
# 0   B -0.568404 -0.007169
# 1   D  0.142918  0.535551
# 2   D  0.142918 -0.579379

# %% [markdown]
# # LEFT JIONS
# <br>
# Note: In some databases, LEFT JOIN is called LEFT OUTER JOIN.
# <br>
# <br>
# In SQL, LEFT JION returns all records from the left table (table1), and the matched records from the right table (table2).
# <br>
# The result is NULL from the right side, if there is no match.
# <br>
# <br>
# In Pandas, we can achieve this by adding the fourth parameter 'left' in the merge() as shown below.
# <br>
# It will show all records from df1.

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key   value_x   value_y
# 0   A -0.437040       NaN
# 1   B -0.568404 -0.007169
# 2   C  1.054222       NaN
# 3   D  0.142918  0.535551
# 4   D  0.142918 -0.579379

# %% [markdown]
# # RIGHT JIONS
# <br>
# Note: In some databases, RIGHT JOIN is called RIGHT OUTER JOIN.
# <br>
# <br>
# In SQL, RIGHT JION returns all records from the right table (table2), and the matched records from the left table (table1).
# <br>
# The result is NULL from the left side, if there is no match.
# <br>
# <br>
# In Pandas, we can achieve this by adding the fourth parameter 'right' in the merge() as shown below.
# <br>
# It will show all records from df2.

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key   value_x   value_y
# 0   B -0.568404 -0.007169
# 1   D  0.142918  0.535551
# 2   D  0.142918 -0.579379
# 3   E       NaN  1.493961

# %%
population = pd.read_csv("UNdata_population_total.csv")

combined = pd.merge(lifeExpectancy,population,on = ['Country','Year'],how='left' )
combined.head()
# Out:
#        Country  Year    Value_x  Value Footnotes_x     Value_y  \
# 0  Afghanistan  2012  60.509122                NaN  29824536.0
# 1  Afghanistan  2011  60.065366                NaN  29105480.0
# 2  Afghanistan  2010  59.600098                NaN  28397812.0
# 3  Afghanistan  2009  59.112341                NaN  27708187.0
# 4  Afghanistan  2008  58.607098                NaN  27032197.0
#
#    Value Footnotes_y
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# The Above results shows that the combined table contains the field (column): "Country" , "Year" , "Value_x", and "Value_y".
# <br>
# Value_x denotes the lifeExpectancy values from first dataframe.
# <br>
# Value_y denotes the population values from second dataframe.
# <br>
# Let's rename the field to be more meaningful.

# %%
combined = combined.rename(index=str,columns= {"Value_x": "Life Expectancy","Value_y":"Population" })
combined.head()
# Out:
#        Country  Year  Life Expectancy  Value Footnotes_x  Population  \
# 0  Afghanistan  2012        60.509122                NaN  29824536.0
# 1  Afghanistan  2011        60.065366                NaN  29105480.0
# 2  Afghanistan  2010        59.600098                NaN  28397812.0
# 3  Afghanistan  2009        59.112341                NaN  27708187.0
# 4  Afghanistan  2008        58.607098                NaN  27032197.0
#
#    Value Footnotes_y
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# # UNION - SQL command
# In SQL, UNION operator selects only distinct values by default.
# <br>
# To allow duplicate values, use UNION ALL.
# <br>
# <br>
# In Pandas, we could perform UNION ALL by using concat() method/function.
# <br>
# Assume we created two dataframes with the following values as shown below.

# %%
df1 = pd.DataFrame({'city': ['Chicago', 'San Francisco', 'New York City'], 'rank': range(1, 4)})

df2 = pd.DataFrame({'city': ['Chicago', 'Boston', 'Los Angeles'],'rank': [1, 4, 5]})

# %%
theUnion = pd.concat([df1,df2])
theUnion
# Out:
#             city  rank
# 0        Chicago     1
# 1  San Francisco     2
# 2  New York City     3
# 0        Chicago     1
# 1         Boston     4
# 2    Los Angeles     5

# %% [markdown]
# # TOP N ROWS

# %%
combined.nlargest(10, columns='Life Expectancy')
# Out:
#                    Country  Year  Life Expectancy  Value Footnotes_x  \
# 4703  Hong Kong SAR, China  2012        83.480488                NaN
# 4704  Hong Kong SAR, China  2011        83.421951                NaN
# 9158            San Marino  2011        83.323215                7.0
# 9159            San Marino  2010        83.159379                7.0
# 5284                 Japan  2012        83.096098                NaN
# 9160            San Marino  2009        82.995543                2.0
# 4705  Hong Kong SAR, China  2010        82.978049                NaN
# 5178                 Italy  2012        82.936585                NaN
# 5287                 Japan  2009        82.931463                NaN
# 4809               Iceland  2012        82.917073                NaN
#
#        Population  Value Footnotes_y
# 4703    7154600.0                NaN
# 4704    7071600.0                NaN
# 9158      31048.0                NaN
# 9159      30861.0                NaN
# 5284  127561489.0                NaN
# 9160      30698.0                NaN
# 4705    7024200.0                NaN
# 5178   59539717.0                NaN
# 5287  127557958.0                NaN
# 4809     320716.0                NaN

# %%
combined.groupby(['Country'])
combined.sort_values(['Life Expectancy'], ascending=False)

combined[combined["Country"] =="United States"]
# Out:
#              Country  Year  Life Expectancy  Value Footnotes_x   Population  \
# 11310  United States  2012        78.741463                NaN  313873685.0
# 11311  United States  2011        78.641463                8.0  311582564.0
# 11312  United States  2010        78.541463                NaN  309326295.0
# 11313  United States  2009        78.090244                NaN  306771529.0
# 11314  United States  2008        77.939024                NaN  304093966.0
# 11315  United States  2007        77.839024                NaN  301231207.0
# 11316  United States  2006        77.587805                NaN  298379912.0
# 11317  United States  2005        77.339024                NaN  295516599.0
# 11318  United States  2004        77.339024                NaN  292805298.0
# 11319  United States  2003        76.987805                NaN  290107933.0
# 11320  United States  2002        76.836585                NaN  287625193.0
# 11321  United States  2001        76.736585                NaN  284968955.0
# 11322  United States  2000        76.636585                NaN  282162411.0
# 11323  United States  1999        76.582927                NaN  279040000.0
# 11324  United States  1998        76.580488                NaN  275854000.0
# 11325  United States  1997        76.429268                NaN  272657000.0
# 11326  United States  1996        75.996585                NaN  269394000.0
# 11327  United States  1995        75.621951                NaN  266278000.0
# 11328  United States  1994        75.574390                NaN  263126000.0
# 11329  United States  1993        75.419512                NaN  259919000.0
# 11330  United States  1992        75.642195                NaN  256514000.0
# 11331  United States  1991        75.365854                NaN  252981000.0
# 11332  United States  1990        75.214634                NaN  249623000.0
# 11333  United States  1989        75.017073                NaN  246819000.0
# 11334  United States  1988        74.765854                NaN  244499000.0
# 11335  United States  1987        74.765854                NaN  242289000.0
# 11336  United States  1986        74.614634                NaN  240133000.0
# 11337  United States  1985        74.563415                NaN  237924000.0
# 11338  United States  1984        74.563415                NaN  235825000.0
# 11339  United States  1983        74.463415                NaN  233792000.0
# 11340  United States  1982        74.360976                NaN  231664000.0
# 11341  United States  1981        74.007317                NaN  229466000.0
# 11342  United States  1980        73.658537                NaN  227225000.0
# 11343  United States  1979        73.804878                NaN  225055000.0
# 11344  United States  1978        73.356098                NaN  222585000.0
# 11345  United States  1977        73.256098                NaN  220239000.0
# 11346  United States  1976        72.856098                NaN  218035000.0
# 11347  United States  1975        72.604878                NaN  215973000.0
# 11348  United States  1974        71.956098                NaN  213854000.0
# 11349  United States  1973        71.356098                NaN  211909000.0
# 11350  United States  1972        71.156098                NaN  209896000.0
# 11351  United States  1971        71.107317                NaN  207661000.0
# 11352  United States  1970        70.807317                NaN  205052000.0
# 11353  United States  1969        70.507317                NaN  202677000.0
# 11354  United States  1968        69.951220                NaN  200706000.0
# 11355  United States  1967        70.560976                NaN  198712000.0
# 11356  United States  1966        70.212195                NaN  196560000.0
# 11357  United States  1965        70.214634                NaN  194303000.0
# 11358  United States  1964        70.165854                NaN  191889000.0
# 11359  United States  1963        69.917073                NaN  189242000.0
# 11360  United States  1962        70.119512                NaN  186538000.0
# 11361  United States  1961        70.270732                NaN  183691000.0
# 11362  United States  1960        69.770732                NaN  180671000.0
#
#        Value Footnotes_y
# 11310                NaN
# 11311                NaN
# 11312                NaN
# 11313                NaN
# 11314                NaN
# 11315                NaN
# 11316                NaN
# 11317                NaN
# 11318                NaN
# 11319                NaN
# 11320                NaN
# 11321                NaN
# 11322                NaN
# 11323                NaN
# 11324                NaN
# 11325                NaN
# 11326                NaN
# 11327                NaN
# 11328                NaN
# 11329                NaN
# 11330                NaN
# 11331                NaN
# 11332                NaN
# 11333                NaN
# 11334                NaN
# 11335                NaN
# 11336                NaN
# 11337                NaN
# 11338                NaN
# 11339                NaN
# 11340                NaN
# 11341                NaN
# 11342                NaN
# 11343                NaN
# 11344                NaN
# 11345                NaN
# 11346                NaN
# 11347                NaN
# 11348                NaN
# 11349                NaN
# 11350                NaN
# 11351                NaN
# 11352                NaN
# 11353                NaN
# 11354                NaN
# 11355                NaN
# 11356                NaN
# 11357                NaN
# 11358                NaN
# 11359                NaN
# 11360                NaN
# 11361                NaN
# 11362                NaN
